# %% [markdown]
# # Day 2 — NLP: From Text to Numbers
# **ComplianceGPT Lab · REU 2026 · Tuesday June 30**
#
# Yesterday you got ~90% accuracy — but only because someone handed you perfectly extracted features.
# Today: work directly with raw text. No hand-crafted features.
#
# The progression:
# 1. **Bag of Words** — ignore word order, just count occurrences
# 2. **TF-IDF** — weight rare words more, common words less
# 3. **The semantic gap** — why TF-IDF still can't tell 'court order' from 'judicial mandate'
#
# **No GPU needed. Runs on your laptop.**

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics.pairwise import cosine_similarity
print('Imports OK')
# Out:
# Imports OK

# %%
# ── Simulated HIPAA scenario text ────────────────────────────────────────
# Raw text versions of the same 80 scenarios from Day 1
# (In the real pipeline these come from court case documents)

scenarios = [
    ("A federal judge signed a court order requiring the hospital to produce patient records", "PERMITTED"),
    ("The patient signed an authorization form allowing the clinic to share her diagnosis", "PERMITTED"),
    ("A law enforcement officer requested records claiming they were needed for an investigation", "DENIED"),
    ("The hospital disclosed records to the treating physician for continued care", "PERMITTED"),
    ("A researcher obtained a waiver of authorization from the IRB and accessed de-identified data", "PERMITTED"),
    ("The health plan disclosed member records to an employer without authorization", "DENIED"),
    ("A court issued a judicial mandate requiring production of mental health records", "PERMITTED"),
    ("The hospital faxed records to an unverified number without patient consent", "DENIED"),
    ("The patient's attorney subpoenaed records with proper satisfactory assurances on file", "PERMITTED"),
    ("An officer implied there might be a court order and the hospital disclosed records", "DENIED"),
    ("A business associate accessed the database without a signed BAA", "DENIED"),
    ("Treatment records were shared with a specialist under a referral arrangement", "PERMITTED"),
    ("The hospital disclosed records pursuant to a lawful subpoena with patient notification", "PERMITTED"),
    ("Records were sold to a marketing firm without authorization", "DENIED"),
    ("The patient verbally consented and the clinic disclosed to the family member", "DENIED"),  # verbal not sufficient
    ("A court order signed by the presiding judge required immediate production", "PERMITTED"),
    ("The covered entity disclosed to comply with a mandatory reporting statute", "PERMITTED"),
    ("The officer said the records were required and the hospital complied", "DENIED"),
    ("A public health authority requested identifiable records for outbreak investigation", "PERMITTED"),
    ("The employee's supervisor requested medical records without signed authorization", "DENIED"),
] * 4  # repeat to get 80 samples

texts  = [s[0] for s in scenarios]
labels = [s[1] for s in scenarios]

print(f'{len(texts)} scenarios')
print('PERMITTED:', labels.count('PERMITTED'), '  DENIED:', labels.count('DENIED'))
# Out:
# 80 scenarios
# PERMITTED: 44   DENIED: 36

# %% [markdown]
# ## Step 1 — Bag of Words
#
# The simplest possible text representation: count how many times each word appears.
# Word order doesn't matter. 'court order' and 'order court' are identical.
# Each scenario becomes a vector with one dimension per unique word in the vocabulary.

# %%
# ── Bag of Words ──────────────────────────────────────────────────────────
bow = CountVectorizer(stop_words='english', max_features=200)
X_bow = bow.fit_transform(texts)

print(f'Vocabulary size: {len(bow.vocabulary_)} words')
print(f'Feature matrix shape: {X_bow.shape}  (80 scenarios × {X_bow.shape[1]} word-counts)')

# Top words
word_counts = np.asarray(X_bow.sum(axis=0)).flatten()
top_words = pd.Series(word_counts, index=bow.get_feature_names_out()).sort_values(ascending=False)[:15]
print('\nTop 15 words:')
print(top_words.to_string())

# Train logistic regression on BoW
lr = LogisticRegression(max_iter=1000, random_state=42)
scores_bow = cross_val_score(lr, X_bow, labels, cv=5, scoring='accuracy')
print(f'\nBag-of-Words accuracy: {scores_bow.mean():.1%} ± {scores_bow.std():.1%}')
# Out:
# Vocabulary size: 92 words
# Feature matrix shape: (80, 92)  (80 scenarios × 92 word-counts)
#
# Top 15 words:
# records          56
# disclosed        24
# hospital         24
# patient          24
# signed           20
# authorization    20
# court            16
# requested        12
# officer          12
# order            12
# health           12
# accessed          8
# clinic            8
# required          8
# member            8
#
# Bag-of-Words accuracy: 100.0% ± 0.0%

# %% [markdown]
# ## Step 2 — TF-IDF
#
# **TF-IDF = Term Frequency × Inverse Document Frequency**
#
# The idea: 'the', 'a', 'and' appear in *every* document — they're useless for classification.
# But 'subpoena' appears in only 3 scenarios — it's highly informative.
# TF-IDF automatically downweights common words and upweights rare, informative ones.

# %%
# ── TF-IDF ────────────────────────────────────────────────────────────────
tfidf = TfidfVectorizer(stop_words='english', max_features=200, ngram_range=(1,2))
X_tfidf = tfidf.fit_transform(texts)

print(f'TF-IDF vocabulary: {X_tfidf.shape[1]} terms (including bigrams)')

scores_tfidf = cross_val_score(lr, X_tfidf, labels, cv=5, scoring='accuracy')
print(f'TF-IDF accuracy:    {scores_tfidf.mean():.1%} ± {scores_tfidf.std():.1%}')
print(f'BoW accuracy:       {scores_bow.mean():.1%} ± {scores_bow.std():.1%}')
print(f'Improvement:        {(scores_tfidf.mean() - scores_bow.mean())*100:+.1f} points')

# Most informative features
lr_tfidf = LogisticRegression(max_iter=1000, random_state=42).fit(X_tfidf, labels)
feat_names = tfidf.get_feature_names_out()
coefs = pd.Series(lr_tfidf.coef_[0], index=feat_names).sort_values()
print('\nStrongest DENIED predictors:')
print(coefs.head(5).to_string())
print('\nStrongest PERMITTED predictors:')
print(coefs.tail(5).to_string())
# Out:
# TF-IDF vocabulary: 200 terms (including bigrams)
# TF-IDF accuracy:    100.0% ± 0.0%
# BoW accuracy:       100.0% ± 0.0%
# Improvement:        +0.0 points
#
# Strongest DENIED predictors:
# officer           -0.882932
# member            -0.641149
# implied court     -0.491599
# implied           -0.491599
# officer implied   -0.491599
#
# Strongest PERMITTED predictors:
# physician           0.372753
# records treating    0.372753
# requiring           0.413041
# production          0.431897
# judge               0.446561

# %% [markdown]
# ## Step 3 — The Semantic Gap
#
# TF-IDF improved accuracy. But it has a fundamental limitation: it treats every word as independent.
# 'court order' and 'judicial mandate' mean the same thing legally — but to TF-IDF they're completely unrelated.
#
# Let's measure this directly.

# %%
# ── The semantic gap in TF-IDF space ────────────────────────────────────
phrases = [
    'A court order signed by the judge required production',
    'A judicial mandate from the presiding bench required production',
    'An officer claimed records were needed for the investigation',
    'The hospital disclosed records to the treating physician',
]

phrase_vecs = tfidf.transform(phrases).toarray()
sim = cosine_similarity(phrase_vecs)

print('Cosine similarity between phrases (TF-IDF):')
print('                                               [A]    [B]    [C]    [D]')
labels_p = ['[A] court order         ',
             '[B] judicial mandate    ',
             '[C] officer investigation',
             '[D] treating physician  ']
for i, row in enumerate(sim):
    vals = '  '.join(f'{v:.2f}' for v in row)
    print(f'  {labels_p[i]}  {vals}')

print()
print('TF-IDF thinks:')
print(f'  court order ↔ judicial mandate:  {sim[0,1]:.2f}  (correct label: both PERMITTED)')
print(f'  court order ↔ officer request:   {sim[0,2]:.2f}  (correct label: DENIED vs PERMITTED)')
print()
print('These should be FAR apart but look CLOSE — and CLOSE but look FAR.')
print('TF-IDF has no concept of semantic meaning. It only sees word overlap.')
# Out:
# Cosine similarity between phrases (TF-IDF):
#                                                [A]    [B]    [C]    [D]
#   [A] court order           1.00  0.25  0.00  0.00
#   [B] judicial mandate      0.25  1.00  0.00  0.00
#   [C] officer investigation  0.00  0.00  1.00  0.03
#   [D] treating physician    0.00  0.00  0.03  1.00
#
# TF-IDF thinks:
#   court order ↔ judicial mandate:  0.25  (correct label: both PERMITTED)
#   court order ↔ officer request:   0.00  (correct label: DENIED vs PERMITTED)
#
# These should be FAR apart but look CLOSE — and CLOSE but look FAR.
# TF-IDF has no concept of semantic meaning. It only sees word overlap.

# %%
# ── YOUR CODE ────────────────────────────────────────────────────────────
# 1. Add 2 new phrases of your own (from the HIPAA scenarios above)
#    that should be semantically similar but TF-IDF would rate as dissimilar
phrases = [
    "A federal judge signed a court order requiring the hospital to produce patient records",
    "The healthcare provider turned over the file only after receiving a signed judicial order",
    ]
# 2. Compute their cosine similarity and print it

phrase_vecs = tfidf.transform(phrases).toarray()
sim = cosine_similarity(phrase_vecs)
print('Cosine similarity between phrases (TF-IDF):')
print('                           [A]   [B]')
labels_p = ['[A] court order       ',
             '[B] judicial directive    ']
for i, row in enumerate(sim):
    vals = '  '.join(f'{v:.2f}' for v in row)
    print(f'  {labels_p[i]}  {vals}')

# 3. Which word in TF-IDF vocabulary would help bridge 'court order' and
#    'judicial mandate'? Print the TF-IDF weight of that word.
#tfidf.vocabulary_ #used this command to view possible words
#I will use order since it appears in both

print('')
idx = tfidf.vocabulary_["order"]
print(phrase_vecs[0][idx])
tfidf.vocabulary_
# Out:
# Cosine similarity between phrases (TF-IDF):
#                            [A]   [B]
#   [A] court order         1.00  0.15
#   [B] judicial directive      0.15  1.00
#
# 0.1985458295816104
# {'federal': np.int64(60),
#  'judge': np.int64(89),
#  'signed': np.int64(186),
#  'court': np.int64(34),
#  'order': np.int64(121),
#  'requiring': np.int64(173),
#  'hospital': np.int64(71),
#  'produce': np.int64(140),
#  'patient': np.int64(127),
#  'records': np.int64(150),
#  'federal judge': np.int64(61),
#  'judge signed': np.int64(91),
#  'signed court': np.int64(189),
#  'court order': np.int64(36),
#  'order requiring': np.int64(123),
#  'requiring hospital': np.int64(174),
#  'hospital produce': np.int64(75),
#  'produce patient': np.int64(141),
#  'patient records': np.int64(131),
#  'authorization': np.int64(14),
#  'form': np.int64(65),
#  'allowing': np.int64(3),
#  'clinic': np.int64(23),
#  'share': np.int64(182),
#  'diagnosis': np.int64(42),
#  'patient signed': np.int64(132),
#  'signed authorization': np.int64(187),
#  'authorization form': np.int64(15),
#  'form allowing': np.int64(66),
#  'allowing clinic': np.int64(4),
#  'clinic share': np.int64(25),
#  'share diagnosis': np.int64(183),
#  'law': np.int64(94),
#  'enforcement': np.int64(52),
#  'officer': np.int64(117),
#  'requested': np.int64(166),
#  'claiming': np.int64(21),
#  'needed': np.int64(110),
#  'investigation': np.int64(84),
#  'law enforcement': np.int64(95),
#  'enforcement officer': np.int64(53),
#  'officer requested': np.int64(119),
#  'requested records': np.int64(169),
#  'records claiming': np.int64(151),
#  'claiming needed': np.int64(22),
#  'needed investigation': np.int64(111),
#  'disclosed': np.int64(43),
#  'physician': np.int64(134),
#  'continued': np.int64(32),
#  'care': np.int64(20),
#  'hospital disclosed': np.int64(73),
#  'disclosed records': np.int64(47),
#  'records treating': np.int64(160),
#  'physician continued': np.int64(135),
#  'continued care': np.int64(33),
#  'researcher': np.int64(176),
#  'obtained': np.int64(115),
#  'irb': np.int64(85),
#  'accessed': np.int64(0),
#  'identified': np.int64(78),
#  'data': np.int64(39),
#  'researcher obtained': np.int64(177),
#  'obtained waiver': np.int64(116),
#  'authorization irb': np.int64(16),
#  'irb accessed': np.int64(86),
#  'accessed identified': np.int64(2),
#  'identified data': np.int64(79),
#  'health': np.int64(67),
#  'plan': np.int64(136),
#  'member': np.int64(106),
#  'employer': np.int64(50),
#  'health plan': np.int64(69),
#  'plan disclosed': np.int64(137),
#  'disclosed member': np.int64(46),
#  'member records': np.int64(107),
#  'records employer': np.int64(152),
#  'employer authorization': np.int64(51),
#  'issued': np.int64(87),
#  'judicial': np.int64(92),
#  'mandate': np.int64(98),
#  'production': np.int64(142),
#  'mental': np.int64(108),
#  'court issued': np.int64(35),
#  'issued judicial': np.int64(88),
#  'judicial mandate': np.int64(93),
#  'mandate requiring': np.int64(99),
#  'requiring production': np.int64(175),
#  'production mental': np.int64(143),
#  'mental health': np.int64(109),
#  'health records': np.int64(70),
#  'faxed': np.int64(58),
#  'number': np.int64(113),
#  'consent': np.int64(29),
#  'hospital faxed': np.int64(74),
#  'faxed records': np.int64(59),
#  'records unverified': np.int64(161),
#  'number patient': np.int64(114),
#  'patient consent': np.int64(129),
#  'attorney': np.int64(10),
#  'subpoenaed': np.int64(198),
#  'proper': np.int64(144),
#  'satisfactory': np.int64(180),
#  'assurances': np.int64(8),
#  'file': np.int64(62),
#  'patient attorney': np.int64(128),
#  'attorney subpoenaed': np.int64(11),
#  'subpoenaed records': np.int64(199),
#  'records proper': np.int64(154),
#  'proper satisfactory': np.int64(145),
#  'satisfactory assurances': np.int64(181),
#  'assurances file': np.int64(9),
#  'implied': np.int64(82),
#  'officer implied': np.int64(118),
#  'implied court': np.int64(83),
#  'order hospital': np.int64(122),
#  'business': np.int64(18),
#  'associate': np.int64(6),
#  'database': np.int64(40),
#  'baa': np.int64(17),
#  'business associate': np.int64(19),
#  'associate accessed': np.int64(7),
#  'accessed database': np.int64(1),
#  'database signed': np.int64(41),
#  'signed baa': np.int64(188),
#  'shared': np.int64(184),
#  'specialist': np.int64(193),
#  'referral': np.int64(162),
#  'arrangement': np.int64(5),
#  'records shared': np.int64(157),
#  'shared specialist': np.int64(185),
#  'specialist referral': np.int64(194),
#  'referral arrangement': np.int64(163),
#  'pursuant': np.int64(148),
#  'lawful': np.int64(96),
#  'subpoena': np.int64(196),
#  'notification': np.int64(112),
#  'records pursuant': np.int64(155),
#  'pursuant lawful': np.int64(149),
#  'lawful subpoena': np.int64(97),
#  'subpoena patient': np.int64(197),
#  'patient notification': np.int64(130),
#  'sold': np.int64(191),
#  'marketing': np.int64(102),
#  'firm': np.int64(63),
#  'records sold': np.int64(159),
#  'sold marketing': np.int64(192),
#  'marketing firm': np.int64(103),
#  'firm authorization': np.int64(64),
#  'consented': np.int64(30),
#  'family': np.int64(56),
#  'patient verbally': np.int64(133),
#  'consented clinic': np.int64(31),
#  'clinic disclosed': np.int64(24),
#  'disclosed family': np.int64(45),
#  'family member': np.int64(57),
#  'presiding': np.int64(138),
#  'required': np.int64(170),
#  'immediate': np.int64(80),
#  'order signed': np.int64(124),
#  'signed presiding': np.int64(190),
#  'presiding judge': np.int64(139),
#  'judge required': np.int64(90),
#  'required immediate': np.int64(172),
#  'immediate production': np.int64(81),
#  'covered': np.int64(37),
#  'entity': np.int64(54),
#  'comply': np.int64(27),
#  'mandatory': np.int64(100),
#  'reporting': np.int64(164),
#  'statute': np.int64(195),
#  'covered entity': np.int64(38),
#  'entity disclosed': np.int64(55),
#  'disclosed comply': np.int64(44),
#  'comply mandatory': np.int64(28),
#  'mandatory reporting': np.int64(101),
#  'reporting statute': np.int64(165),
#  'said': np.int64(178),
#  'complied': np.int64(26),
#  'officer said': np.int64(120),
#  'said records': np.int64(179),
#  'records required': np.int64(156),
#  'required hospital': np.int64(171),
#  'hospital complied': np.int64(72),
#  'public': np.int64(146),
#  'authority': np.int64(12),
#  'identifiable': np.int64(76),
#  'outbreak': np.int64(125),
#  'public health': np.int64(147),
#  'health authority': np.int64(68),
#  'authority requested': np.int64(13),
#  'requested identifiable': np.int64(167),
#  'identifiable records': np.int64(77),
#  'records outbreak': np.int64(153),
#  'outbreak investigation': np.int64(126),
#  'employee': np.int64(48),
#  'medical': np.int64(104),
#  'employee supervisor': np.int64(49),
#  'requested medical': np.int64(168),
#  'medical records': np.int64(105),
#  'records signed': np.int64(158)}

# %% [markdown]
# **Reflection:**
#
# 1. TF-IDF improved over BoW. What specific property of legal text does TF-IDF handle better than BoW?
#
# 2. The cosine similarity between 'court order' and 'judicial mandate' was near 0 in TF-IDF space.
#    What would need to be different about the representation for them to score high?
#
# 3. Think about the adversarial case: 'an officer implied there might be a court order'.
#    How would TF-IDF classify this? How would a human classify it? Why the difference?
#
# *Your answers:*
#
# 1. The fact that it automatically downweights common words and upweights rare informative ones makes it better for legal text since you need to see what stands out.
#
# 2. I think it is because they have no overlapping words, and they would need some sort of semantic embedding to be seen as similar.
#
# 3. TF-IDF would say probably classify it as having a court order, since is it looking for specfic words, while a human would be able to determine that there was NOT a court order. This is because TF-IDF is not looking at every single word to weigh what it means.
#
# ---
# **Next:** Day 3 (`day3_embeddings.ipynb`) — word embeddings give words *geometric meaning*.
# 'court order' and 'judicial mandate' end up close. But 'implied there might be' still trips up the model. That's the LLM problem.
